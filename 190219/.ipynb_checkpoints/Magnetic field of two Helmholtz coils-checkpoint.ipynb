# %% [markdown]
# # Magentic fields

# %%
using PyPlot

# %%
μ0 = 4pi*1e-7 #N/A^2;

# %%
function getMagField(_I, _R, _n, x_loc_from_coil)
    μ0*_I/2 * R^2 *inv.((R^2 + x_loc_from_coil.^2).^(3/2)) *_n
end
# Out:
# getMagField (generic function with 1 method)

# %%
R = 0.065 # m
I = 1 # A
n = 1000; # winding

# %%
d = R;
x = -d/2:0.001:d/2
B1_mT = getMagField(I, R, n, x + d/2)*1e3
B2_mT = getMagField(I, R, n, x - d/2)*1e3;

plot(x, B1_mT)
plot(x, B2_mT)
plot(x, B1_mT + B2_mT)
legend(["B1","B2","B"]);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
d = 2*R;
x = -d/2:0.001:d/2
B1_mT = getMagField(I, R, n, x + d/2)*1e3
B2_mT = getMagField(I, R, n, x - d/2)*1e3;

plot(x*1e3, B1_mT)
plot(x*1e3, B2_mT)
plot(x*1e3, B1_mT + B2_mT)
legend(["B1","B2","B"]); xlabel("[mm]"); ylabel("[mT]")
title("R = $(R*1e3)mm, d = $(d*1e3)mm");
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
R = 65*1e-3
d = R*1.1172*1e-3
x = -d/2:0.001:d/2
B1_mT = getMagField(I, R, n, x + d/2)*1e3
B2_mT = getMagField(I, R, n, x - d/2)*1e3;

plot(x*1e3, B1_mT)
plot(x*1e3, B2_mT)
plot(x*1e3, B1_mT + B2_mT)
legend(["B1","B2","B"]); xlabel("[mm]"); ylabel("[mT]")
title("R = $(R*1e3)mm, d = $(d*1e3)mm");
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
R = 65*1e-3
d = 172*1e-3
x = -d/2:0.001:d/2
B1_mT = getMagField(I, R, n, x + d/2)*1e3
B2_mT = getMagField(I, R, n, x - d/2)*1e3;

B = B1_mT + B2_mT;
v, id1 = findmin(abs.(x .+ 0.025))
v, id2 = findmin(abs.(x .- 0.025))
id3 = ceil(Int, length(x)/2)
B[id1], B[id3], (B[id1]/B[id3]-1)*100
# Out:
# (91.00000000000001, 11.061037016288664, 10.581439261519053, 4.532443488228832)

# %%
_n = [400, 1000, 1200]
_R = [80, 80, 80]*1e-3
_d = [0, 162, 192]*1e-3
# Out:
# 3-element Array{Float64,1}:
#  0.0
#  0.162
#  0.192

# %%
i = 3
R = _R[i]
d = _d[i]
n = _n[i]
x = -d/2:0.001:d/2
B1_mT = getMagField(I, R, n, x + d/2)*1e3
B2_mT = getMagField(I, R, n, x - d/2)*1e3;

B = B1_mT + B2_mT;
v, id1 = findmin(abs.(x .+ 0.025))
v, id2 = findmin(abs.(x .- 0.025))
id3 = ceil(Int, length(x)/2)
B[id1], B[id3], (B[id1]/B[id3]-1)*100
# Out:
# (5.524201594100958, 4.945570344906694, 11.699990270893235)

# %%
35*35
# Out:
# 1225

# %%
w_coil = 0.8118
n = [35, 35]
w_coil.*n
# Out:
# 2-element Array{Float64,1}:
#  28.413
#  28.413
